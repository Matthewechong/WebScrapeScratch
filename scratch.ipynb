# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# %%
# URL to look up website
URL = 'https://www.smogon.com/dex/ss/formats/ou/'
# Information to scrape
attributes = ['PokemonAltRow-name',
              'PokemonAltRow-types',
              'PokemonAltRow-abilities',
              'PokemonAltRow-tags',
              'PokemonAltRow-hp',
              'PokemonAltRow-atk',
              'PokemonAltRow-def',
              'PokemonAltRow-spa',
              'PokemonAltRow-spd',
              'PokemonAltRow-spe']


PATH = '/Users/chongster/Desktop/Code/Python/WebScraping_Scratch/chromedriver'

# %%
driver = webdriver.Chrome(PATH)
driver.get(URL)

data = driver.find_element(By.CLASS_NAME, value='theme--dark')
data = data.find_element(By.ID, value='container')
data = data.find_element(By.CLASS_NAME, value='DexBody')
data = data.find_element(By.CLASS_NAME, value='DexContent')
data = data.find_elements(By.TAG_NAME, value='section')
pokemons = data[2].find_elements(By.CLASS_NAME, value='PokemonAltRow')
all_data = []
for pokemon in pokemons:
    temp = {}
    for atrribute in attributes:
        value = pokemon.find_element(By.CLASS_NAME, value=atrribute).text
        temp[atrribute] = value
    all_data.append(temp)

driver.quit()
# Out:
# /var/folders/93/dy9vvt2s2rl2nhwc9km6br000000gn/T/ipykernel_18042/2079549278.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)

# %%
df = pd.DataFrame(all_data)
# Out:
#       PokemonAltRow-name PokemonAltRow-types        PokemonAltRow-abilities  \
# 0            Barraskewda               Water                 Propeller Tail
# 1                Bisharp         Dark\nSteel              Defiant\nPressure
# 2            Blacephalon         Fire\nGhost                    Beast Boost
# 3                Blissey              Normal           Healer\nSerene Grace
# 4               Buzzwole       Bug\nFighting                    Beast Boost
# 5               Clefable               Fairy            Cute Charm\nUnaware
# 6            Corviknight       Flying\nSteel          Mirror Armor\nUnnerve
# 7              Dragapult       Dragon\nGhost        Clear Body\nInfiltrator
# 8              Dragonite      Dragon\nFlying                    Inner Focus
# 9             Ferrothorn        Grass\nSteel                   Anticipation
# 10              Garchomp      Dragon\nGround                     Rough Skin
# 11               Heatran         Fire\nSteel                     Flame Body
# 12               Kartana        Grass\nSteel                    Beast Boost
# 13      Landorus-Therian      Ground\nFlying                     Intimidate
# 14             Magnezone     Electric\nSteel               Analytic\nSturdy
# 15              Melmetal               Steel                      Iron Fist
# 16                   Mew             Psychic                    Synchronize
# 17       Ninetales-Alola          Ice\nFairy                     Snow Cloak
# 18              Pelipper       Water\nFlying             Drizzle\nRain Dish
# 19             Regieleki            Electric                     Transistor
# 20             Rillaboom               Grass                   Grassy Surge
# 21               Slowbro      Water\nPsychic         Oblivious\nRegenerator
# 22        Slowking-Galar     Poison\nPsychic  Curious Medicine\nRegenerator
# 23             Tapu Fini        Water\nFairy                    Misty Surge
# 24             Tapu Koko     Electric\nFairy                 Electric Surge
# 25             Tapu Lele      Psychic\nFairy                  Psychic Surge
# 26      Tornadus-Therian              Flying                    Regenerator
# 27               Toxapex       Poison\nWater            Limber\nRegenerator
# 28             Tyranitar          Rock\nDark                    Sand Stream
# 29  Urshifu-Rapid-Strike     Fighting\nWater                    Unseen Fist
# 30               Victini       Psychic\nFire                   Victory Star
# 31             Volcanion         Fire\nWater                   Water Absorb
# 32             Volcarona           Bug\nFire                     Flame Body
# 33               Weavile           Dark\nIce                     Pickpocket
# 34                Zapdos    Electric\nFlying                       Pressure
# 35          Zapdos-Galar    Fighting\nFlying                        Defiant
# 36               Zeraora            Electric                    Volt Absorb
#
#    PokemonAltRow-tags PokemonAltRow-hp PokemonAltRow-atk PokemonAltRow-def  \
# 0                  OU           HP\n61          Atk\n123           Def\n60
# 1                  OU           HP\n65          Atk\n125          Def\n100
# 2                  OU           HP\n53          Atk\n127           Def\n53
# 3                  OU          HP\n255           Atk\n10           Def\n10
# 4                  OU          HP\n107          Atk\n139          Def\n139
# 5                  OU           HP\n95           Atk\n70           Def\n73
# 6                  OU           HP\n98           Atk\n87          Def\n105
# 7                  OU           HP\n88          Atk\n120           Def\n75
# 8                  OU           HP\n91          Atk\n134           Def\n95
# 9                  OU           HP\n74           Atk\n94          Def\n131
# 10                 OU          HP\n108          Atk\n130           Def\n95
# 11                 OU           HP\n91           Atk\n90          Def\n106
# 12                 OU           HP\n59          Atk\n181          Def\n131
# 13                 OU           HP\n89          Atk\n145           Def\n90
# 14                 OU           HP\n70           Atk\n70          Def\n115
# 15                 OU          HP\n135          Atk\n143          Def\n143
# 16                 OU          HP\n100          Atk\n100          Def\n100
# 17                 OU           HP\n73           Atk\n67           Def\n75
# 18                 OU           HP\n60           Atk\n50          Def\n100
# 19                 OU           HP\n80          Atk\n100           Def\n50
# 20                 OU          HP\n100          Atk\n125           Def\n90
# 21                 OU           HP\n95           Atk\n75          Def\n110
# 22                 OU           HP\n95           Atk\n65           Def\n80
# 23                 OU           HP\n70           Atk\n75          Def\n115
# 24                 OU           HP\n70          Atk\n115           Def\n85
# 25                 OU           HP\n70           Atk\n85           Def\n75
# 26                 OU           HP\n79          Atk\n100           Def\n80
# 27                 OU           HP\n50           Atk\n63          Def\n152
# 28                 OU          HP\n100          Atk\n134          Def\n110
# 29                 OU          HP\n100          Atk\n130          Def\n100
# 30                 OU          HP\n100          Atk\n100          Def\n100
# 31                 OU           HP\n80          Atk\n110          Def\n120
# 32                 OU           HP\n85           Atk\n60           Def\n65
# 33                 OU           HP\n70          Atk\n120           Def\n65
# 34                 OU           HP\n90           Atk\n90           Def\n85
# 35                 OU           HP\n90          Atk\n125           Def\n90
# 36                 OU           HP\n88          Atk\n112           Def\n75
#
#    PokemonAltRow-spa PokemonAltRow-spd PokemonAltRow-spe
# 0            SpA\n60           SpD\n50          Spe\n136
# 1            SpA\n60           SpD\n70           Spe\n70
# 2           SpA\n151           SpD\n79          Spe\n107
# 3            SpA\n75          SpD\n135           Spe\n55
# 4            SpA\n53           SpD\n53           Spe\n79
# 5            SpA\n95           SpD\n90           Spe\n60
# 6            SpA\n53           SpD\n85           Spe\n67
# 7           SpA\n100           SpD\n75          Spe\n142
# 8           SpA\n100          SpD\n100           Spe\n80
# 9            SpA\n54          SpD\n116           Spe\n20
# 10           SpA\n80           SpD\n85          Spe\n102
# 11          SpA\n130          SpD\n106           Spe\n77
# 12           SpA\n59           SpD\n31          Spe\n109
# 13          SpA\n105           SpD\n80           Spe\n91
# 14          SpA\n130           SpD\n90           Spe\n60
# 15           SpA\n80           SpD\n65           Spe\n34
# 16          SpA\n100          SpD\n100          Spe\n100
# 17           SpA\n81          SpD\n100          Spe\n109
# 18           SpA\n95           SpD\n70           Spe\n65
# 19          SpA\n100           SpD\n50          Spe\n200
# 20           SpA\n60           SpD\n70           Spe\n85
# 21          SpA\n100           SpD\n80           Spe\n30
# 22          SpA\n110          SpD\n110           Spe\n30
# 23           SpA\n95          SpD\n130           Spe\n85
# 24           SpA\n95           SpD\n75          Spe\n130
# 25          SpA\n130          SpD\n115           Spe\n95
# 26          SpA\n110           SpD\n90          Spe\n121
# 27           SpA\n53          SpD\n142           Spe\n35
# 28           SpA\n95          SpD\n100           Spe\n61
# 29           SpA\n63           SpD\n60           Spe\n97
# 30          SpA\n100          SpD\n100          Spe\n100
# 31          SpA\n130           SpD\n90           Spe\n70
# 32          SpA\n135          SpD\n105          Spe\n100
# 33           SpA\n45           SpD\n85          Spe\n125
# 34          SpA\n125           SpD\n90          Spe\n100
# 35           SpA\n85           SpD\n90          Spe\n100
# 36          SpA\n102           SpD\n80          Spe\n143

# %%
# Clean Data
clean_df = df.rename(columns = {'PokemonAltRow-name' : 'Name',
              'PokemonAltRow-types' : 'Type',
              'PokemonAltRow-abilities' : 'Abilities',
              'PokemonAltRow-tags' : 'Tier',
              'PokemonAltRow-hp' : 'Hp',
              'PokemonAltRow-atk' : 'Atk',
              'PokemonAltRow-def' : 'Def' ,
              'PokemonAltRow-spa' : 'Spa',
              'PokemonAltRow-spd' : 'Spd',
              'PokemonAltRow-spe' : 'Spe'})

# %%
clean_df
temp = clean_df
stats = ['Hp', 'Atk', 'Def', 'Spa', 'Spd', 'Spe']

def clean_stats(stat):
    data = stat.split('\n')
    return data[len(data)-1]
for stat in stats:
    temp[stat] = temp[stat].apply(clean_stats)

temp.to_csv('pokemon_data.csv')
